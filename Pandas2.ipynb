# %%
#pandas
import pandas as pd

tabela = pd.read_excel(r"C:\Users\User\Desktop\dados_brutos.xlsx")
display(tabela)
# Out:
#      Unnamed: 0                                                  0  \
# 0             0  Agenda de Leilões no Período de 01/03/2022 a 3...
# 1             0                            Circunscrição: Brasília
# 2             0                                         07/03/2022
# 3             0                                              12:00
# 4             0                                              12:20
# ..          ...                                                ...
# 188           0                                              12:50
# 189           0                                              13:00
# 190           0                                         29/03/2022
# 191           0                                              13:40
# 192           0  Circunscrição: Nenhum Leilão Agendado para o P...
#
#                                                      1  \
# 0                                                  NaN
# ...

# %%
tabela =pd.read_excel(r"C:\Users\User\Desktop\dados_brutos.xlsx",
                  header=0,
                  names=['col1','col2','col3']
                 )
tabela.head()
# Out:
#                                                                                                                                    col1  \
# 0 Agenda de Leilões no Período de 01/03/2022 a 30... NaN                                                                            NaN
#   Circunscrição: Brasília                            NaN                                                                            NaN
#   07/03/2022                                         Topo da Página                                                                 NaN
#   12:00                                              Vara: SEXTA VARA CÍVEL DE BRASÍLIAPartes: CARLO...  Processo: 01039282220058070001
#   12:20                                              Vara: TERCEIRA VARA DE EXECUÇÃO DE TÍTULOS EXTR...  Processo: 07025924020198070001
#
#                                                                                                                 col2  \
# ...

# %%
tabela.rename(columns={'col1': 'Data_Hora'}, inplace=True)
tabela.head()
# Out:
#                                                                                                                               Data_Hora  \
# 0 Agenda de Leilões no Período de 01/03/2022 a 30... NaN                                                                            NaN
#   Circunscrição: Brasília                            NaN                                                                            NaN
#   07/03/2022                                         Topo da Página                                                                 NaN
#   12:00                                              Vara: SEXTA VARA CÍVEL DE BRASÍLIAPartes: CARLO...  Processo: 01039282220058070001
#   12:20                                              Vara: TERCEIRA VARA DE EXECUÇÃO DE TÍTULOS EXTR...  Processo: 07025924020198070001
#
#                                                                                                                 col2  \
# ...

# %%
tabela.rename(columns={'col2': 'Vara'}, inplace=True)
tabela.head()
# Out:
#                                                                                                                               Data_Hora  \
# 0 Agenda de Leilões no Período de 01/03/2022 a 30... NaN                                                                            NaN
#   Circunscrição: Brasília                            NaN                                                                            NaN
#   07/03/2022                                         Topo da Página                                                                 NaN
#   12:00                                              Vara: SEXTA VARA CÍVEL DE BRASÍLIAPartes: CARLO...  Processo: 01039282220058070001
#   12:20                                              Vara: TERCEIRA VARA DE EXECUÇÃO DE TÍTULOS EXTR...  Processo: 07025924020198070001
#
#                                                                                                                 Vara  \
# ...

# %%
tabela.rename(columns={'col3': 'teste'}, inplace=True)
tabela.head()
# Out:
#                                                                                                                               Data_Hora  \
# 0 Agenda de Leilões no Período de 01/03/2022 a 30... NaN                                                                            NaN
#   Circunscrição: Brasília                            NaN                                                                            NaN
#   07/03/2022                                         Topo da Página                                                                 NaN
#   12:00                                              Vara: SEXTA VARA CÍVEL DE BRASÍLIAPartes: CARLO...  Processo: 01039282220058070001
#   12:20                                              Vara: TERCEIRA VARA DE EXECUÇÃO DE TÍTULOS EXTR...  Processo: 07025924020198070001
#
#                                                                                                                 Vara  \
# ...

# %%
tabela['col4'] = 0
tabela.head()
# Out:
#                                                                                                                               Data_Hora  \
# 0 Agenda de Leilões no Período de 01/03/2022 a 30... NaN                                                                            NaN
#   Circunscrição: Brasília                            NaN                                                                            NaN
#   07/03/2022                                         Topo da Página                                                                 NaN
#   12:00                                              Vara: SEXTA VARA CÍVEL DE BRASÍLIAPartes: CARLO...  Processo: 01039282220058070001
#   12:20                                              Vara: TERCEIRA VARA DE EXECUÇÃO DE TÍTULOS EXTR...  Processo: 07025924020198070001
#
#                                                                                                                 Vara  \
# ...
